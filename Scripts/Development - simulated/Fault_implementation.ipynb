# %% [markdown]
# # Implementation of faults in processed data

# %%
import pandas as pd
import numpy as np   
import plotly.graph_objects as go

# %%
fault1 = pd.read_csv('/Users/sararhiger/Desktop/Master thesis /Data/Processed data/Fault1_Window_dataprocessed.csv')
fault2 = pd.read_csv('/Users/sararhiger/Desktop/Master thesis /Data/Processed data/Fault2_LowSetpoint_dataprocessed.csv')
fault3 = pd.read_csv('/Users/sararhiger/Desktop/Master thesis /Data/Processed data/Fault3_CO2_dataprocessed.csv')
fault4 = pd.read_csv('/Users/sararhiger/Desktop/Master thesis /Data/Processed data/Fault4_HighSetpoint_dataprocessed.csv')
multi = pd.read_csv('/Users/sararhiger/Desktop/Master thesis /Data/Processed data/Multiclass_dataprocessed.csv')

fault4_experiment_1 = pd.read_csv('/Users/sararhiger/Desktop/Master thesis /Data/Processed data/Performance VS faults/1_Fault4_dataprocessed.csv')
fault4_experiment_3 = pd.read_csv('/Users/sararhiger/Desktop/Master thesis /Data/Processed data/Performance VS faults/3_Fault4_dataprocessed.csv')
fault1_experiment_1 = pd.read_csv('/Users/sararhiger/Desktop/Master thesis /Data/Processed data/Performance VS faults/1_Fault1_dataprocessed.csv')
fault1_experiment_3 = pd.read_csv('/Users/sararhiger/Desktop/Master thesis /Data/Processed data/Performance VS faults/3_Fault1_dataprocessed.csv')
fault1_experiment_7 = pd.read_csv('/Users/sararhiger/Desktop/Master thesis /Data/Processed data/Performance VS faults/7_Fault1_dataprocessed.csv')

df_simulated = fault1

# %% [markdown]
# ### Funktion til implementering af fejl

# %%
from datetime import datetime

def time_mask(df, start_time: str, end_time: str):
    return (start_time <= df["Time"]) & (df["Time"] <= end_time)

# %% [markdown]
# # Add FDD fault codes according to true simulated values in zone 1 for training

# %% [markdown]
# ## Zone 1 - Fault 1 - Open window

# %%
# Tidspunkt 1 
t1, t2 = '2023-01-04 10:00:00', '2023-01-04 14:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 1'] = 1  

# Tidspunkt 2 
t1, t2 = '2023-01-06 10:00:00', '2023-01-06 11:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 1'] = 1  

# Tidspunkt 3 
t1, t2 = '2023-01-08 10:00:00', '2023-01-08 13:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 1'] = 1

# Tidspunkt 4  
t1, t2 = '2023-01-14 12:00:00', '2023-01-14 14:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 1'] = 1

# Tidspunkt 5  
t1, t2 = '2023-01-20 13:00:00', '2023-01-20 15:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 1'] = 1

# Tidspunkt 6
t1, t2 = '2023-01-26 09:00:00', '2023-01-26 12:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 1'] = 1  

# Tidspunkt 7
t1, t2 = '2023-02-07 10:00:00', '2023-02-07 13:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 1'] = 1  

# Tidspunkt 8
t1, t2 = '2023-02-12 12:00:00', '2023-02-12 14:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 1'] = 1

# Tidspunkt 9
t1, t2 = '2023-02-24 09:00:00', '2023-02-24 10:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 1'] = 1

# Tidspunkt 10
t1, t2 = '2023-02-24 14:00:00', '2023-02-24 15:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 1'] = 1

# Tidspunkt 11
t1, t2 = '2023-11-05 09:00:00', '2023-11-05 11:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 1'] = 1

# Tidspunkt 12
t1, t2 = '2023-11-12 11:00:00', '2023-11-12 13:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 1'] = 1  

# Tidspunkt 13
t1, t2 = '2023-11-21 12:00:00', '2023-11-21 14:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 1'] = 1  

# Tidspunkt 14
t1, t2 = '2023-12-07 10:00:00', '2023-12-07 13:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 1'] = 1

# Tidspunkt 15
t1, t2 = '2023-12-15 08:00:00', '2023-12-15 10:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 1'] = 1

# Tidspunkt 15
#t1, t2 = '2023-12-17 12:00:00', '2023-12-17 13:00:00'
#mask = time_mask(df_simulated, t1, t2)
#df_simulated.loc[mask, 'FDD, zone 1'] = 1

# %% [markdown]
# ## Zone 1 - Fault 2 - Low setpoint

# %%
# Tidspunkt 1 
t1, t2 = '2023-01-05 15:00:00', '2023-01-05 23:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 1'] = 2  

# Tidspunkt 2 
t1, t2 = '2023-01-06 00:00:00', '2023-01-06 08:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 1'] = 2 

# Tidspunkt 3 februar
t1, t2 = '2023-01-21 17:00:00', '2023-01-21 23:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 1'] = 2

# Tidspunkt 4 
t1, t2 = '2023-01-22 00:00:00', '2023-01-22 08:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 1'] = 2

# Tidspunkt 5 
t1, t2 = '2023-02-03 15:00:00', '2023-02-03 23:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 1'] = 2

# Tidspunkt 6
t1, t2 = '2023-02-04 00:00:00', '2023-02-04 09:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 1'] = 2 

# Tidspunkt 7 
t1, t2 = '2023-02-19 17:00:00', '2023-02-19 23:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 1'] = 2  

# Tidspunkt 8
t1, t2 = '2023-02-20 00:00:00', '2023-02-20 10:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 1'] = 2

# Tidspunkt 9 
t1, t2 = '2023-11-16 15:00:00', '2023-11-16 23:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 1'] = 2

# Tidspunkt 10
t1, t2 = '2023-11-17 00:00:00', '2023-11-17 07:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 1'] = 2

# Tidspunkt 11  
t1, t2 = '2023-12-10 17:00:00', '2023-12-10 23:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 1'] = 2

# Tidspunkt 12 
t1, t2 = '2023-12-11 00:00:00', '2023-12-11 07:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 1'] = 2

# %% [markdown]
# ## Zone 1 - Fault 3 - Defect CO2 sensor

# %%
# Tidspunkt 1 
t1, t2 = '2023-03-01 00:00:00', '2023-03-15 00:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 1'] = 3
df_simulated.loc[mask, 'CO2, ppm (vol), zone 1'] = 200

# Tidspunkt 2 
t1, t2 = '2023-05-13 00:00:00', '2023-05-27 00:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 1'] = 3 
df_simulated.loc[mask, 'CO2, ppm (vol), zone 1'] = 200

# Tidspunkt 3 
t1, t2 = '2023-08-16 00:00:00', '2023-08-28 00:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 1'] = 3
df_simulated.loc[mask, 'CO2, ppm (vol), zone 1'] = 200

# Tidspunkt 4 
t1, t2 = '2023-10-10 00:00:00', '2023-10-23 00:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 1'] = 3
df_simulated.loc[mask, 'CO2, ppm (vol), zone 1'] = 200

# Tidspunkt 5 
t1, t2 = '2023-10-28 00:00:00', '2023-11-04 00:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 1'] = 3
df_simulated.loc[mask, 'CO2, ppm (vol), zone 1'] = 200

# %% [markdown]
# ## Zone 1 - Fault 4 - High Setpoint

# %%
# Tidspunkt 1 
t1, t2 = '2023-01-08 16:00:00', '2023-01-08 23:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 1'] = 4  

# Tidspunkt 2 
t1, t2 = '2023-01-09 00:00:00', '2023-01-09 07:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 1'] = 4 

# Tidspunkt 1 
t1, t2 = '2023-01-12 16:00:00', '2023-01-12 23:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 1'] = 4  

# Tidspunkt 2 
t1, t2 = '2023-01-13 00:00:00', '2023-01-13 10:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 1'] = 4 

# Tidspunkt 3 februar
t1, t2 = '2023-01-27 18:00:00', '2023-01-27 23:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 1'] = 4

# Tidspunkt 4 
t1, t2 = '2023-01-28 00:00:00', '2023-01-28 07:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 1'] = 4

# Tidspunkt 5 
t1, t2 = '2023-02-05 16:00:00', '2023-02-05 23:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 1'] = 4

# Tidspunkt 6
t1, t2 = '2023-02-06 00:00:00', '2023-02-06 08:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 1'] = 4 

# Tidspunkt 7 
t1, t2 = '2023-02-24 18:00:00', '2023-02-24 23:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 1'] = 4  

# Tidspunkt 8
t1, t2 = '2023-02-25 00:00:00', '2023-02-25 09:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 1'] = 4

# Tidspunkt 7 
t1, t2 = '2023-02-26 18:00:00', '2023-02-26 23:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 1'] = 4  

# Tidspunkt 8
t1, t2 = '2023-02-27 00:00:00', '2023-02-27 09:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 1'] = 4

# Tidspunkt 9 
t1, t2 = '2023-11-08 15:00:00', '2023-11-08 23:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 1'] = 4

# Tidspunkt 10
t1, t2 = '2023-11-09 00:00:00', '2023-11-09 07:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 1'] = 4

# Tidspunkt 9 
t1, t2 = '2023-11-18 16:00:00', '2023-11-18 23:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 1'] = 4

# Tidspunkt 10
t1, t2 = '2023-11-19 00:00:00', '2023-11-19 06:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 1'] = 4

# Tidspunkt 9 
t1, t2 = '2023-11-23 19:00:00', '2023-11-23 23:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 1'] = 4

# Tidspunkt 10
t1, t2 = '2023-11-24 00:00:00', '2023-11-24 08:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 1'] = 4

# Tidspunkt 11  
t1, t2 = '2023-12-01 16:00:00', '2023-12-01 23:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 1'] = 4

# Tidspunkt 12 
t1, t2 = '2023-12-02 00:00:00', '2023-12-02 08:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 1'] = 4

# Tidspunkt 11  
t1, t2 = '2023-12-13 18:00:00', '2023-12-13 23:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 1'] = 4

# Tidspunkt 12 
t1, t2 = '2023-12-14 00:00:00', '2023-12-14 07:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 1'] = 4

# Tidspunkt 11  
t1, t2 = '2023-12-20 18:00:00', '2023-12-20 23:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 1'] = 4

# Tidspunkt 12 
t1, t2 = '2023-12-21 00:00:00', '2023-12-21 06:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 1'] = 4

# %% [markdown]
# ## Add FDD codes corresponding to true simulated faults for test in zone 8

# %% [markdown]
# ## Zone 8 - Fault 1 - Open window

# %%
# Tidspunkt 1
t1, t2 = '2023-01-15 09:00:00', '2023-01-15 10:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 8'] = 1  

# Tidspunkt 2
t1, t2 = '2023-01-15 14:00:00', '2023-01-15 15:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 8'] = 1  

# Tidspunkt 3
t1, t2 = '2023-02-18 12:00:00', '2023-02-18 14:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 8'] = 1  

# Tidspunkt 4 
t1, t2 = '2023-11-08 09:00:00', '2023-11-08 11:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 8'] = 1  

# Tidspunkt 5
t1, t2 = '2023-12-21 11:00:00', '2023-12-21 13:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 8'] = 1

# %% [markdown]
# ## Zone 8 - Fault 2 - Low setpoint

# %%
# Tidspunkt 1 
t1, t2 = '2023-01-07 15:00:00', '2023-01-07 24:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 8'] = 2

# Tidspunkt 2 
t1, t2 = '2023-01-08 00:00:00', '2023-01-08 09:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 8'] = 2  

# Tidspunkt 3 
t1, t2 = '2023-01-27 17:00:00', '2023-01-27 24:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 8'] = 2

# Tidspunkt 4 
t1, t2 = '2023-01-28 00:00:00', '2023-01-28 08:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 8'] = 2

# Tidspunkt 5 
t1, t2 = '2023-02-16 17:00:00', '2023-02-16 24:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 8'] = 2

# Tidspunkt 6
t1, t2 = '2023-02-17 00:00:00', '2023-02-17 09:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 8'] = 2  

# Tidspunkt 7 
t1, t2 = '2023-12-09 13:00:00', '2023-12-09 24:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 8'] = 2 

# Tidspunkt 8
t1, t2 = '2023-12-10 00:00:00', '2023-12-10 07:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 8'] = 2

# %% [markdown]
# ## Zone 8 - Fault 3 - Defect co2 sensor

# %%
# Tidspunkt 1 
t1, t2 = '2023-04-16 00:00:00', '2023-04-29 00:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 8'] = 3
df_simulated.loc[mask, 'CO2, ppm (vol), zone 8'] = 200

# Tidspunkt 2 
t1, t2 = '2023-07-14 00:00:00', '2023-07-30 00:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 8'] = 3
df_simulated.loc[mask, 'CO2, ppm (vol), zone 8'] = 200

# %% [markdown]
# ## Zone 8 - Fault 4 - High setpoint 25 degrees

# %%
# Tidspunkt 1 
t1, t2 = '2023-01-12 16:00:00', '2023-01-12 23:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 8'] = 4

# Tidspunkt 2 
t1, t2 = '2023-01-13 00:00:00', '2023-01-13 08:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 8'] = 4

# Tidspunkt 3 
t1, t2 = '2023-01-20 18:00:00', '2023-01-20 23:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 8'] = 4

# Tidspunkt 4 
t1, t2 = '2023-01-21 00:00:00', '2023-01-21 07:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 8'] = 4

# Tidspunkt 5 
t1, t2 = '2023-02-22 18:00:00', '2023-02-22 23:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 8'] = 4

# Tidspunkt 6
t1, t2 = '2023-02-23 00:00:00', '2023-02-23 08:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 8'] = 4  

# Tidspunkt 7 
t1, t2 = '2023-12-16 14:00:00', '2023-12-16 23:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 8'] = 4 

# Tidspunkt 8
t1, t2 = '2023-12-17 00:00:00', '2023-12-17 06:00:00'
mask = time_mask(df_simulated, t1, t2)
df_simulated.loc[mask, 'FDD, zone 8'] = 4

# %% [markdown]
# ## Ready for training

# %%
df_simulated.to_csv('/Users/sararhiger/Desktop/Master thesis /Data/Processed data/Fault1_Window_dataprocessed.csv', index=False)

# %% [markdown]
# ## Plots

# %%
fig = go.Figure()

# Plot the temperature curve
fig.add_trace(go.Scatter(
    x=df_simulated['Time'], 
    y=df_simulated['Mean air temperature, degC, zone 8'], 
    mode='lines', 
    name='Zone 8 faulty operation (Temperature) fault markers',
))

# Make sure 'Time' is datetime
df_simulated['Time'] = pd.to_datetime(df_simulated['Time'])

# Get one timestamp per day (midnight)
tick_vals = df_simulated['Time'].dt.normalize().drop_duplicates().sort_values()

# Update layout
fig.update_layout(
    title="Temperatures in zone 8 2023 (Simulated)",
    xaxis_title="Time",
    yaxis_title="Temperature (°C)",
    legend_title="Temperature Curves",
    template="plotly",
    width = 1800,
    xaxis=dict(
        tickmode='array',
        tickvals=tick_vals,
        tickformat="%b %d"  # Example: Apr 01
    )
)

fig.show()

# %%
fig = go.Figure()

# Plot the temperature curve
fig.add_trace(go.Scatter(
    x=df_simulated['Time'], 
    y=df_simulated['Mean air temperature, degC, zone 8'], 
    mode='lines', 
    name='Zone 8 faulty operation (Temperature) fault markers',
    yaxis='y1'
))

# Add heating consumption on second y-axis as a dotted line
fig.add_trace(go.Scatter(
    x=df_simulated['Time'],
    y=df_simulated['Heating consumption, zone 8'],  # Replace with your actual column name
    mode='lines',
    name='Heating Consumption',
    line=dict(dash='dot'),
    yaxis='y2'
))

# Ensure 'Time' is datetime
df_simulated['Time'] = pd.to_datetime(df_simulated['Time'])

# Get one timestamp per day (midnight)
tick_vals = df_simulated['Time'].dt.normalize().drop_duplicates().sort_values()

# Update layout
fig.update_layout(
    title="Temperatures and Heating Consumption in Zone 8",
    xaxis_title="Time",
    yaxis=dict(
        title="Temperature (°C)",
        side="left"
    ),
    yaxis2=dict(
        title="Heating Consumption (Normalized)",  # Update unit as needed
        overlaying='y',
        side='right',
        showgrid=False
    ),
    legend_title="Legend",
    template="plotly",
    width=1200,
    height = 500,
    xaxis=dict(
        tickmode='array',
        tickvals=tick_vals,
        tickformat="%b %d"
    )
)

fig.show()

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(x=df_simulated['Time'], y=df_simulated['Local heating units, W, zone 8'], mode='lines', name='Heating consumption zone 8'))

# Make sure 'Time' is datetime
df_simulated['Time'] = pd.to_datetime(df_simulated['Time'])

# Get one timestamp per day (midnight)
tick_vals = df_simulated['Time'].dt.normalize().drop_duplicates().sort_values()

fig.update_layout(
    title="Normalized heating consumption zone 8 2023 (Simulated)",
    xaxis_title="Time",
    yaxis_title="Heating (Normalized)",
    legend_title="Temperature Curves",
    template="plotly",
    width = 1800,
    xaxis=dict(
        tickmode='array',
        tickvals=tick_vals,
        tickformat="%b %d"  # Example: Apr 01 newline 08:00
    )
)

fig.show()

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(x=df_simulated['Time'], y=df_simulated['CO2, ppm (vol), zone 8'], mode='lines', name='CO2 concentration in zone 8'))

# Make sure 'Time' is datetime
df_simulated['Time'] = pd.to_datetime(df_simulated['Time'])

# Get one timestamp per day (midnight)
tick_vals = df_simulated['Time'].dt.normalize().drop_duplicates().sort_values()

fig.update_layout(
    title="CO2 concentration in zone 8 (Simulated)",
    xaxis_title="Time",
    yaxis_title="CO2 concentration (PPM)",
    legend_title="CO2 Curves",
    template="plotly",
    xaxis=dict(
        tickmode='array',
        tickvals=tick_vals,
        tickformat="%b %d"  # Example: Apr 01
    )
)

# Show the plot
fig.show()

# %%
# Create figure
fig = go.Figure()

# Plot the temperature curve
fig.add_trace(go.Scatter(
    x=df_simulated['Time'], 
    y=df_simulated['Local heating units, W, zone 8'], 
    mode='lines', 
    name='Zone 8 heating consumption',
))

# Find timestamps where "FDD, zone 1" is NOT 0
fault_indices = df_simulated['FDD, zone 8'] != 0
fault_times = df_simulated.loc[fault_indices, 'Time']
fault_temps = df_simulated.loc[fault_indices, 'Local heating units, W, zone 8']

# Add markers for fault occurrences
fig.add_trace(go.Scatter(
    x=fault_times,
    y=fault_temps,
    mode='markers',
    marker=dict(color='red', size=10, symbol='x'),
    name='Fault implemented (FDD ≠ 0)'
))

# Customize layout
fig.update_layout(
    title="Normalized heating consumption Zone 8 with fault markers",
    xaxis_title="Time",
    yaxis_title="Heating (Normalized)",
    legend_title="Legend",
    template="plotly", 
)

# Show the plot
fig.show()
